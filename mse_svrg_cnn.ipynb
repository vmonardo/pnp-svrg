# %%
from imports import *

# %%
params = create_problem(img_path='./data/mse_images/tilt_008.tiff')

psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=params['original'], title="Original")
psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=params['noisy'], title="Initialization")

svrg_out1, svrg_time, svrg_psnr, svrg_zs = pnp_svrg(params=params,
                                                   denoiser='cnn',
                                                   eta=25e3, tt=10, T2=10, 
                                                   mini_batch_size=int(20e3), verbose=False)

psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=svrg_out1, title="PnP-SVRG")

# %%
params = create_problem(img_path='./data/mse_images/tilt_008.tiff')

psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=params['original'], title="Original")
psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=params['noisy'], title="Initialization")

svrg_out2, svrg_time, svrg_psnr, svrg_zs = pnp_svrg(params=params,
                                                   denoiser='cnn',
                                                   eta=25e3, tt=20, T2=10, 
                                                   mini_batch_size=int(20e3), verbose=False)

psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=svrg_out2, title="PnP-SVRG")

# %%
params = create_problem(img_path='./data/mse_images/tilt_008.tiff')

psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=params['original'], title="Original")
psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=params['noisy'], title="Initialization")

svrg_out3, svrg_time, svrg_psnr, svrg_zs = pnp_svrg(params=params,
                                                   denoiser='cnn',
                                                   eta=25e3, tt=30, T2=10, 
                                                   mini_batch_size=int(20e3), verbose=False)

psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=svrg_out3, title="PnP-SVRG")

# %%
params = create_problem(img_path='./data/mse_images/tilt_008.tiff')

psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=params['original'], title="Original")
psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=params['noisy'], title="Initialization")

svrg_out4, svrg_time, svrg_psnr, svrg_zs = pnp_svrg(params=params,
                                                   denoiser='cnn',
                                                   eta=25e3, tt=40, T2=10, 
                                                   mini_batch_size=int(20e3), verbose=False)

psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=svrg_out4, title="PnP-SVRG")

# %%
params = create_problem(img_path='./data/mse_images/tilt_008.tiff')

psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=params['original'], title="Original")
psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=params['noisy'], title="Initialization")

sgd_out1, sgd_time, sgd_psnr, sgd_zs = pnp_sgd(params=params,
                                                   denoiser='cnn',
                                                   eta=20e3, tt=10, 
                                                   mini_batch_size=int(20e3), verbose=False)

psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=svrg_out1, title="PnP-SGD")

# %%
params = create_problem(img_path='./data/mse_images/tilt_008.tiff')

psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=params['original'], title="Original")
psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=params['noisy'], title="Initialization")

sgd_out2, sgd_time, sgd_psnr, sgd_zs = pnp_sgd(params=params,
                                                   denoiser='cnn',
                                                   eta=20e3, tt=20, 
                                                   mini_batch_size=int(20e3), verbose=False)

psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=svrg_out2, title="PnP-SGD")

# %%
params = create_problem(img_path='./data/mse_images/tilt_008.tiff')

psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=params['original'], title="Original")
psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=params['noisy'], title="Initialization")

sgd_out3, sgd_time, sgd_psnr, sgd_zs = pnp_sgd(params=params,
                                                   denoiser='cnn',
                                                   eta=20e3, tt=30, 
                                                   mini_batch_size=int(20e3), verbose=False)

psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=svrg_out3, title="PnP-SGD")

# %%
params = create_problem(img_path='./data/mse_images/tilt_008.tiff')

psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=params['original'], title="Original")
psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=params['noisy'], title="Initialization")

sgd_out4, sgd_time, sgd_psnr, sgd_zs = pnp_sgd(params=params,
                                                   denoiser='cnn',
                                                   eta=20e3, tt=40, 
                                                   mini_batch_size=int(20e3), verbose=False)

psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=svrg_out4, title="PnP-SGD")

# %%
show_grid([torch.Tensor(params['original']), torch.Tensor(params['noisy']), 
           torch.Tensor(svrg_out1), 
          torch.Tensor(svrg_out2), 
          torch.Tensor(svrg_out3), 
          torch.Tensor(svrg_out4)], 
          ['Original','Initial Estimate',
           "PnP-SVRG, PSNR %.2f, t = 10s" % peak_signal_noise_ratio(params['original'], svrg_out1), 
          "PnP-SVRG, PSNR %.2f, t = 20s" % peak_signal_noise_ratio(params['original'], svrg_out2), 
          "PnP-SVRG, PSNR %.2f, t = 30s" % peak_signal_noise_ratio(params['original'], svrg_out3),
          "PnP-SVRG, PSNR %.2f, t = 40s" % peak_signal_noise_ratio(params['original'], svrg_out4)], rows=3, cols=2, figsize=(10,10))

plt.savefig("./figures/visual_over_time.png")

# %%
show_grid([torch.Tensor(params['original']), torch.Tensor(params['noisy']), 
           torch.Tensor(svrg_out), torch.Tensor(svrg_out-params['original'])], 
          ['Original','Initial Estimate',"PnP-SVRG, PSNR %.2f" % peak_signal_noise_ratio(params['original'], svrg_out), 
           "Difference"], rows=2, cols=2, figsize=(8,8))

print(svrg_out-params['original'])

# %%
params = create_problem(img_path='./data/mse_images/tilt_011.tiff')

psnr_display(img_path='./data/mse_images/tilt_011.tiff', output=params['original'], title="Original")
psnr_display(img_path='./data/mse_images/tilt_011.tiff', output=params['noisy'], title="Initialization")

svrg_out, svrg_time, svrg_psnr, svrg_zs = pnp_svrg(params=params,
                                                   denoiser='cnn',
                                                   eta=20e3, tt=20, T2=10, 
                                                   mini_batch_size=int(20e3), verbose=False)

psnr_display(img_path='./data/mse_images/tilt_011.tiff', output=svrg_out, title="SVRG")

# %%
show_grid([torch.Tensor(params['original']), torch.Tensor(params['noisy']), 
           torch.Tensor(svrg_out), torch.Tensor(svrg_out-params['original'])], 
          ['Original','Initial Estimate',"PnP-SVRG, PSNR %.2f" % peak_signal_noise_ratio(params['original'], svrg_out), 
           "Difference"], rows=2, cols=2, figsize=(8,8))

# %%
params = create_problem(img_path='./data/mse_images/tilt_016.tiff')

psnr_display(img_path='./data/mse_images/tilt_016.tiff', output=params['original'], title="Original")
psnr_display(img_path='./data/mse_images/tilt_016.tiff', output=params['noisy'], title="Initialization")

svrg_out, svrg_time, svrg_psnr, svrg_zs = pnp_svrg(params=params,
                                                   denoiser='cnn',
                                                   eta=20e3, tt=20, T2=10, 
                                                   mini_batch_size=int(20e3), verbose=False)

psnr_display(img_path='./data/mse_images/tilt_016.tiff', output=svrg_out, title="SVRG")

# %%
show_grid([torch.Tensor(params['original']), torch.Tensor(params['noisy']), 
           torch.Tensor(svrg_out), torch.Tensor(svrg_out-params['original'])], 
          ['Original','Initial Estimate',"PnP-SVRG, PSNR %.2f" % peak_signal_noise_ratio(params['original'], svrg_out), 
           "Difference"], rows=2, cols=2, figsize=(8,8))

# %%
params = create_problem(img_path='./data/mse_images/tilt_017.tiff')

psnr_display(img_path='./data/mse_images/tilt_017.tiff', output=params['original'], title="Original")
psnr_display(img_path='./data/mse_images/tilt_017.tiff', output=params['noisy'], title="Initialization")

svrg_out, svrg_time, svrg_psnr, svrg_zs = pnp_svrg(params=params,
                                                   denoiser='cnn',
                                                   eta=20e3, tt=20, T2=10, 
                                                   mini_batch_size=int(20e3), verbose=False)

psnr_display(img_path='./data/mse_images/tilt_017.tiff', output=svrg_out, title="SVRG")
psnr_display(img_path='./data/mse_images/tilt_017.tiff', output=svrg_out-params['original'], title="Difference")

# %%
show_grid([torch.Tensor(params['original']), torch.Tensor(params['noisy']), 
           torch.Tensor(svrg_out), torch.Tensor(svrg_out-params['original'])], 
          ['Original','Initial Estimate',"PnP-SVRG, PSNR %.2f" % peak_signal_noise_ratio(params['original'], svrg_out), 
           "Difference"], rows=2, cols=2, figsize=(8,8))

# %%
params = create_problem(img_path='./data/mse_images/tilt_025.tiff')

psnr_display(img_path='./data/mse_images/tilt_025.tiff', output=params['original'], title="Original")
psnr_display(img_path='./data/mse_images/tilt_025.tiff', output=params['noisy'], title="Initialization")

svrg_out, svrg_time, svrg_psnr, svrg_zs = pnp_svrg(params=params,
                                                   denoiser='cnn',
                                                   eta=20e3, tt=20, T2=10, 
                                                   mini_batch_size=int(20e3), verbose=False)

psnr_display(img_path='./data/mse_images/tilt_025.tiff', output=svrg_out, title="SVRG")

# %%
fig = show_grid([torch.Tensor(params['original']), torch.Tensor(params['noisy']), 
           torch.Tensor(svrg_out), torch.Tensor(svrg_out-params['original'])], 
          ['Original','Initial Estimate',"PnP-SVRG, PSNR %.2f" % peak_signal_noise_ratio(params['original'], svrg_out), 
           "Difference"], rows=2, cols=2, figsize=(8,8))

# %%
def grad(z, indices, meas, F, N):
    index = np.nonzero(indices)
    
    res = np.zeros((N,N), dtype=complex)
    
    F_i = F[index[0],:]
    F_j = F[index[1],:]
    
    res[index] = ((F_i @ z * F_j).sum(-1) - meas[index])
    
    return (np.real(np.conj(F) @ res @ np.conj(F.T))/N**2)/len(index[0])

def get_batch(B, MASK):
    H, W = MASK.shape[:2]
    batch = np.zeros((1,H*W))
    tmp = np.linspace(0, H*W - 1, H*W)
    one_locs = tmp[np.matrix.flatten(MASK) == 1].astype(int)
    batch_locs = np.random.choice(one_locs, B, replace=False)
    batch[0, batch_locs] = 1

    # find nonzero batch indices
    return batch.reshape(H,W).astype(int)


def create_problem(img_path=None, img=None, H=256, W=256, sample_prob=0.5, sigma=1.0,         # general params
                   filter_size=0.015, patch_size=5, patch_distance=6, multichannel=True,      # NLM params
                   cnn_sigma=40, device='cuda',                                               # CNN params
                   multia=True, rescale_sigma=True,                                           # TV params
                   noise_est=0.015,                                                           # BM3D params
                   lr_decay=0.999, filter_decay=0.999, cnn_decay=0.9):                        # decay params                   

    if img_path is not None:
        original = np.array(Image.open(img_path).resize((H, W)))
    elif img is not None:
        original = img
    else:
        raise Exception('Need to pass in image path or image')

    original = (original - np.min(original)) / (np.max(original) - np.min(original))

    np.random.seed(0)
    mask = np.random.choice([0, 1], size=(H, W), p=[1 - sample_prob, sample_prob])
    indices = np.transpose(np.nonzero(mask))

#     forig = np.fft.fft2(original)
#     np.random.seed(0)
#     noises = np.random.normal(0, sigma, (H, W))

#     y0 = forig + noises
    y = np.multiply(mask, original)

#     x_init = np.absolute(np.fft.ifft2(y))
    x_init = y

    cnn = Denoiser(net=DnCNN(17), 
                   experiment_name='exp_' + str(cnn_sigma), 
                   data=False, sigma=cnn_sigma, batch_size=20).net.to(device)

#     i, j = np.meshgrid(np.arange(H), np.arange(H))
#     omega = np.exp(-2*math.pi*1J/H)
#     F = np.power(omega, i*j)
    F = np.identity(H)

    return {'noisy': x_init,
            'mask': mask,
            'y': y,
            'original': original,
            'H': H,
            'W': W,
            'F' : F,
            'indices': indices,
            'filter' : filter_size,
            'patch' : dict(patch_size=patch_size, patch_distance=patch_distance, multichannel=multichannel),
            'cnn' : cnn,
            'device' : device,
            'multia' : multia,
            'rescale_sigma' : rescale_sigma,
            'noise_est' : noise_est,
            't' : 0,
            'lr_decay' : lr_decay,
            'filter_decay' : filter_decay,
            'cnn_decay' : cnn_decay}

# %%
params = create_problem(img_path='./data/mse_images/tilt_008.tiff', sample_prob=.9,filter_size=0.02)

psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=params['original'], title="Original")
psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=params['noisy'], title="Initialization")

svrg_out2, svrg_time, svrg_psnr, svrg_zs = pnp_svrg(params=params,
                                                   denoiser='nlm',
                                                   eta=25e3, tt=20, T2=10, 
                                                   mini_batch_size=int(20e3), verbose=False)

psnr_display(img_path='./data/mse_images/tilt_008.tiff', output=svrg_out2, title="PnP-SVRG")
